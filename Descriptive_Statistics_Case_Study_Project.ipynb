# %% [markdown]
# <a href="https://colab.research.google.com/github/azadsimhab/Python-for-Data-Analyst-/blob/main/Descriptive_Statistics_Case_Study_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read the employee dataset file as a pandas Dataframe

data = pd.read_csv('/content/Employee Dataset.csv')

# %%
# Take a brief look at the data

print(data.head)
# Out:
# <bound method NDFrame.head of     id groups  age  healthy_eating  active_lifestyle  salary
# 0    0      A   36               5                 5    2297
# 1    1      A   26               3                 5    1134
# 2    2      A   61               8                 1    4969
# 3    3      O   24               3                 6     902
# 4    4      O   39               6                 2    3574
# 5    5      O   32               5                 3    2761
# 6    6     AB   25               4                 6    1484
# 7    7      B   39               8                 6    3809
# 8    8      A   32               5                 6    2065
# 9    9      A   28               4                 8    1020
# 10  10      A   30               6                 9    1950
# 11  11      O   40               7                 1    4387
# 12  12      O   23               3                 2    1830
# 13  13      O   30               6                 8    2182
# ...

# %%
# Get the dimentions of the dataframe

print(data.shape)
# Out:
# (50, 6)

# %%
# Get the rows names of the dataframe

print(data.index)
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
# Get the column names of the dataframe

print(data.columns)
# Out:
# Index(['id', 'groups', 'age', 'healthy_eating', 'active_lifestyle', 'salary'], dtype='object')

# %%
#look at basic information abour the dataframe

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                50 non-null     int64
#  1   groups            50 non-null     object
#  2   age               50 non-null     int64
#  3   healthy_eating    50 non-null     int64
#  4   active_lifestyle  50 non-null     int64
#  5   salary            50 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 2.5+ KB

# %%
# Visualising the distributions of ratings and compensations
# A scatter plot of employee age and employee salary, healthy_eating and active_lifestyle, health_eating and salary
# A count plot of groups
# A histogram of employee salary

#scatter plot of the "age" and "Employee Salary" features

plt.figure(figsize = (10,5))

sns.scatterplot(data = data, x = 'age', y = 'salary', color = 'blue', edgecolor = 'linen', alpha = 0.5)

plt.title("Scatterplot of Employee Age v/s Employee Salary")
plt.xlabel('Employee Age')
plt.ylabel('Employee Salary')
plt.show()

# %% [markdown]
# Observations:
#
# # We Observe that in general, there is a relationship between age and salary of Employee.
#
# As Age Increases, the salary also Increases, though there are some outliners present as well.

# %%
#Scatter Plot of the "health_eating" and "active_lifestyle" features

plt.figure(figsize = (10,5))

sns.scatterplot(data = data, x = 'healthy_eating', y = 'active_lifestyle', color = 'blue', edgecolor = 'linen', alpha = 0.5)

plt.title("Scatterplot of Healthy Eating v/s Active Lifestyle")
plt.xlabel('Healthy Eating')
plt.ylabel('Active Lifestyle')
plt.show()

# %% [markdown]
# Observations:
#
# We can Observe that in general, there is a relationship between healthy_eating and active_lifestyle of employee.
#
# As healthy_eating increases, the active_lifestyle also increases.

# %%
#create a scatter plot of the "healthy_eating" and "salary" features

plt.figure(figsize = (10,5))

sns.scatterplot(data = data, x = 'healthy_eating', y = 'salary', color = 'blue', edgecolor = 'linen', alpha = 0.5)

plt.title("Scatterplot of Healthy Eating v/s Salary")
plt.xlabel('Healthy Eating')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# Observations:
#
# We observe that in general, there is a arelationship between healthy_eating and salary of employee.
#
# As healthy_eating increases, the salary also increases.

# %%
# create a count plot of the "groups" feature

plt.figure(figsize = (10,5))

sns.countplot(data = data, x = 'groups', edgecolor = 'linen', alpha = 0.7)

plt.title("Count Plot of Groups")
plt.xlabel('Groups')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Observations:
#
# We see tha most employees eirher belong to group A and Group O, with group A having maximum frequency.

# %%
# create a histogram of the "salary" feature

plt.figure(figsize = (11,6))

sns.histplot(data = data, x = 'salary', color = 'orange', edgecolor = 'linen', alpha = 0.7, bins = 10)

plt.title("Histogram of Salary")
plt.xlabel('Salary')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Observations:
# WE see that the salaries are not uniform, which is not necessarily a discrepancy.
#
# But we do observe that there are employees with salaries on either extermities of the histogram.
#
# Based on th histogram, we can see that the count of highest earner employee is very less.

# %% [markdown]
# Following Conditions:
#
# Employees with healthy_eating greater than 8
#
# Employees with Salary less than 1000
#
# Employees with healthy_eating greater than 8 and with slary less than 900

# %%
# Employee healthy_eating is greater than 8

sub1 = data[data['healthy_eating'] > 8]

print(sub1)
# Out:
#     id groups  age  healthy_eating  active_lifestyle  salary
# 26  26      A   62               9                 6     700

# %%
#salary less than 100

sub2 = data[data['salary'] < 900]

print(sub2)
# Out:
#     id groups  age  healthy_eating  active_lifestyle  salary
# 15  15      B   26               3                 8     662
# 18  18      A   27               2                 6     779
# 26  26      A   62               9                 6     700
# 32  32      A   22               3                 8     662
# 35  35      O   27               2                 4     785
# 38  38     AB   26               3                 7     670
# 39  39      B   29               2                 6     779
# 43  43      O   23               4                10     556

# %%
from re import sub
# Employees with healthy_eating greater than 8 and with salary less than 900

sub3 = data[(data['healthy_eating'] > 8) & (data['salary'] < 900)]

print(sub3)
# Out:
#     id groups  age  healthy_eating  active_lifestyle  salary
# 26  26      A   62               9                 6     700

# %% [markdown]
# Observations:
#
# The only employee seemingly facing a discrepancy in salary as compared to healthy_eating is employee who is having id = 26.
#
# The employee with id having 26 has a salary of 700.

# %% [markdown]
# Conclusion:
#
# From the given data, we can use simple visualisations to get a sense of how data are distributed.
#
# We can conduct Preliminary analysis simply by subsetting data sets using well though out thresholds and conditions.
